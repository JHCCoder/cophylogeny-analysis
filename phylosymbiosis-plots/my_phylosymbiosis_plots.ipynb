# %% [markdown]
# # Phylosymbiosis correlation plots

# %% [markdown]
# This notebook produces the plots showing phylosymbiosis correlations, per the methods in Nishida et al.
#
# It uses the data generated by the phylogenetic mantel correlation notebook.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Package Imports

# %%
require(ggplot2)
require(plyr)

#package imports
# Out:
# Loading required package: ggplot2
#
# Loading required package: plyr

# %% [markdown]
# ### Filepaths

# %%
dist_fp <- '../phylosymbiosis/phylo.distance_table.csv'

plot_dir <- '../phylosymbiosis/plots'
dir.create(file.path(plot_dir))
