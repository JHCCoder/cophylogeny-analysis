# %% [markdown]
# # Calculating Mantel correlations across the host phylogeny

# %% [markdown]
# The purpose of this notebook is to calculate Mantel correlations between phylogenetic distance and microbiome dissimilarity at each node of the host phylogenetic tree.
#
# The resulting significance value (and correlation coefficient) can then be plotted against the host phylogeny to visualize changes in the strength of phylosymbiosis across the host phylogeny.

# %% [markdown]
# ## Algorithm
#
# - preorder traverse tree
# - for each node:
#   - grab tips associated with node
#   - filter dm to those tips
#   - grab patristic dm from those tips
#   - calculate mantel
#   - store values on node

# %%
import skbio as skb
import numpy as np
import pandas as pd
import seaborn as sns
from ecopy import Mantel

from matplotlib import pyplot as plt
import pylab as pl
from qiime2 import Artifact
from skbio import TreeNode
from skbio.stats.distance import mantel
from scipy.stats import linregress
from scipy.spatial.distance import squareform, pdist
from os.path import abspath, join
from os import makedirs

# %% [markdown]
# ## Import data

# %% [markdown]
# ### Host Tree

# %%
# Export the wol qza tree to usable format 
# !qiime tools export \
    --input-path /projects/vertebrate_assembly/07-combined-analysis-emp500-woltka/data/tree.qza \
    --output-path /projects/vertebrate_assembly /09-cophylogeny-analysis-jon-sanders/mantel-correlation/data/trees

# %%
tree_dir = abspath('/projects/vertebrate_assembly/09-cophylogeny-analysis-jon-sanders/mantel-correlation/data/trees')
host_tree_fp = join(tree_dir, 'total_timetree_names.all.nwk.tre')
host_tree= skb.io.read(host_tree_fp, format='newick', 
                       into=TreeNode,
                       convert_underscores=False)

host_tips = [x.name for x in host_tree.tips()]

# %%
# Visualize trees! 
print(host_tree.ascii_art())
# Out:
#                                                   /-Catostomus_catostomus
#                                         /13------|
#                                        |         |          /-Gila_robusta
#                                        |          \14------|
#                                        |                    \-Cyprinus_carpio
#                                        |
#                                        |                                                  /-Plethodon_cinereus
#                                        |                                        /11------|
#                                        |                              /10------|          \-Plethodon_shenandoah
#                                        |                             |         |
#                                        |                    /9-------|          \-Aneides_aeneus
#                                        |                   |         |
#                                        |                   |         |          /-Eurycea_bislineata
#                                        |                   |          \19------|
#                                        |                   |                    \-Eurycea_longicauda
#                                        |                   |
#                                        |                   |                    /-Cornufer_guentheri
#                                        |                   |          /8-------|
#                                        |          /56------|         |         |          /-Mantella_aurantiaca
#                                        |         |         |         |          \22------|
#                                        |         |         |         |                    \-Theloderma_corticale
#                                        |         |         |         |
#                                        |         |         |         |                                        /-Dendrobates_tinctorius
#                                        |         |         |         |                              /30------|
#                                        |         |         |         |                             |         |          /-Phyllobates_bicolor
#                                        |         |         |         |                             |          \6-------|
#                                        |         |          \39------|                             |                    \-Phyllobates_terribilis
#                                        |         |                   |                    /43------|
#                                        |         |                   |                   |         |                    /-Pedostibes_hosii
#                                        |         |                   |                   |         |          /27------|
#                                        |         |                   |                   |         |         |         |          /-Anaxyrus_terrestris
#                                        |         |                   |          /42------|          \35------|          \29------|
#                                        |         |                   |         |         |                   |                    \-Incilius_signifer
#                                        |         |                   |         |         |                   |
#                                        |         |                   |         |         |                    \-Atelopus_varius
#                                        |         |                    \47------|         |
#                                        |         |                             |          \-Lepidobatrachus_laevis
#                                        |         |                             |
#                                        |         |                             |          /-Strabomantis_anomalus
#                                        |         |                              \51------|
#                                        |         |                                       |          /-Trachycephalus_resinifictrix
#                                        |         |                                        \48------|
#                                        |         |                                                 |          /-Litoria_infrafrenata
#                                        |         |                                                  \40------|
#                                        |         |                                                            \-Hylomantis_lemur
#                                        |         |
#                                        |         |                                                                                          /-Pseudechis_papuanus
#                                        |         |                                                                                         |
#                                        |         |                                                                                         |                    /-Drymarchon_corais
#                                        |         |                                                                                /38------|                   |
#                                        |         |                                                                               |         |          /60------|                    /-Lampropeltis_getula
#                                        |         |                                                                               |         |         |         |          /55------|
#                                        |         |                                                                               |         |         |          \61------|          \-Lampropeltis_alterna
#                                        |         |                                                                               |          \54------|                   |
#                                        |         |                                                                      /66------|                   |                    \-Elaphe_schrenckii
#                                        |         |                                                                     |         |                   |
#                                        |         |                                                                     |         |                    \-Nerodia_sipedon
#                                        |         |                                                                     |         |
#                                        |         |                                                                     |         |          /-Bitis_arietans
#                                        |         |                                                                     |          \26------|
#                                        |         |                                                                     |                   |          /-Crotalus_viridis
#                                        |         |                                                                     |                    \34------|
#                                        |         |                                                            /88------|                              \-Bothriechis_schlegelii
#                                        |         |                                                           |         |
#                                        |         |                                                           |         |                              /-Morelia_viridis
#                                        |         |                                                           |         |                    /75------|
#                                        |         |                                                           |         |                   |          \-Aspidites_ramsayi
#                                        |         |                                                           |         |          /78------|
#                                        |         |                                                           |         |         |         |          /-Python_molurus
#                                        |         |                                                           |         |         |          \80------|
#                                        |         |                                                           |          \73------|                    \-Python_regius
#                                        |         |                                                           |                   |
#                                        |         |                                                           |                   |                    /-Eunectes_murinus
#                                        |         |                                                           |                   |          /74------|
#                                        |         |                                                           |                    \83------|          \-Corallus_hortulanus
#                                        |         |                                                           |                             |
#                                        |         |                                                           |                              \-Boa_constrictor
#                                        |         |                                                           |
#                                        |         |                                                           |                                        /-Cyclura_collei
#                                        |         |                                                           |                              /86------|
#                                        |         |                                                  /126-----|                             |          \-Iguana_iguana
#                                        |         |                                                 |         |                    /91------|
#                                        |         |                                                 |         |                   |         |          /-Basiliscus_plumifrons
#                                        |         |                                                 |         |                   |         |         |
#                                        |         |                                                 |         |                   |          \92------|                    /-Anolis_smallwoodi
#                                        |         |                                                 |         |                   |                   |          /72------|
#                                        |         |                                                 |         |                   |                    \93------|          \-Anolis_allisoni
#                                        |         |                                                 |         |                   |                             |
#                                        |         |                                                 |         |          /102-----|                              \-Anolis_barbatus
#                                        |         |                                                 |         |         |         |
#                                        |         |                                                 |         |         |         |                    /-Uromastyx_aegyptia
#                                        |         |                                                 |         |         |         |          /65------|
#                                        |         |                                                 |         |         |         |         |         |          /-Gonocephalus_chamaeleontinus
#                                        |         |                                                 |         |         |         |         |          \69------|
#                                        |         |                                                 |         |         |         |         |                   |          /-Physignathus_cocincinus
#                                        |         |                                                 |         |         |          \5-------|                    \71------|
#                                        |         |                                                 |         |         |                   |                              \-Pogona_vitticeps
#                                        |         |                                                 |         |         |                   |
#                                        |         |                   |                             |
#                                        |         |                   |                             |                                                                      /-Oreortyx_pictus
#                                        |         |                   |                             |                                                                     |
#                                        |         |                   |                             |                                                            /117-----|          /-Colinus_virginianus
#                                        |         |                   |                             |                                                           |         |         |
#                                        |         |                   |                             |                                                           |          \118-----|                    /-Callipepla_gambelii
#                                        |         |                   |                             |                                                           |                   |          /120-----|
#                                        |         |                   |                             |                                                  /115-----|                    \119-----|          \-Callipepla_californica
#                                        |         |                   |                             |                                                 |         |                             |
#                                        |         |                   |                             |                                                 |         |                              \-Callipepla_squamata
#                                        |         |                   |                             |                                                 |         |
#                                        |         |                   |                             |                                                 |          \-Cyrtonyx_montezumae
#                                        |         |                   |                             |                                                 |
#                                        |         |                   |                             |                                                 |                              /-Rollulus_rouloul
#                                        |         |                   |                             |                                                 |                    /105-----|
#                                        |         |                   |                             |                                                 |                   |          \-Perdix_perdix
#                                        |         |                   |                             |                                                 |          /177-----|
#                                        |         |                   |                             |                                        /226-----|         |         |          /-Coturnix_coturnix
#                                        |         |                   |                             |                                       |         |         |          \99------|
#                                        |         |                   |                             |                                       |         |         |                    \-Alectoris_graeca
#                                        |         |                   |                             |                                       |         |         |
#                                        |         |                   |                             |                                       |         |         |                    /-Meleagris_gallopavo
#                                        |         |                   |                             |                                       |         |         |                   |
#                                        |         |                   |                             |                                       |         |         |                   |          /-Tetrastes_bonasia
#                                        |         |                   |                             |                                       |         |         |                   |         |
#                                        |         |                   |                             |                                       |         |         |                   |         |                                        /-Lyrurus_tetrix
#                                        |         |                   |                             |                                       |         |         |          /203-----|         |                              /185-----|
#                                        |         |                   |                             |                                       |         |         |         |         |         |                             |          \-Tetrao_urogallus
#                                        |         |                   |                             |                                       |          \227-----|         |         |         |                             |
#                                        |         |                   |                             |                                       |                   |         |         |         |                             |                              /-Tympanuchus_phasianellus
#                                        |         |                   |                             |                                       |                   |         |         |         |                    /176-----|                    /184-----|
#                                        |         |                   |                             |                                       |                   |         |         |         |                   |         |                   |          \-Tympanuchus_cupido
#                                        |         |                   |                             |                                       |                   |         |          \204-----|                   |         |          /182-----|
#                                        |         |                   |                             |                                       |                   |         |                   |                   |         |         |         |          /-Dendragapus_fuliginosus
#                                        |         |                   |                             |                                       |                   |         |                   |                   |          \180-----|          \183-----|
#                                        |         |                   |                             |                                       |                   |         |                   |          /175-----|                   |                    \-Dendragapus_obscurus
#                                        |         |                   |                             |                                       |                   |         |                   |         |         |                   |
#                                        |         |                   |                             |                                       |                   |         |                   |         |         |                    \-Centrocercus_urophasianus
#                                        |         |                   |                             |                                       |                   |         |                   |         |         |
#                                        |         |                   |                             |                                       |                   |         |                   |         |         |          /-Falcipennis_canadensis
#                                        |         |                   |                             |                              /224-----|                   |         |                   |         |         |         |
#                                        |         |                   |                             |                             |         |                    \228-----|                    \205-----|          \191-----|                    /-Lagopus_lagopus
#                                        |         |                   |                             |                             |         |                             |                             |                   |          /192-----|
#                                        |         |                   |                             |                             |         |                             |                             |                    \195-----|          \-Lagopus_muta
#          |         |         |                                       |                   |                             |                             |                                       |          /-Colobus_angolensis
#          |         |         |                                       |                   |                             |                             |                                        \2567----|
#          |         |         |                                       |                   |                             |                             |                                                  \-Colobus_guereza
#          |         |         |                                       |                   |                             |                             |
#          |         |         |                                       |                   |                             |                             |                              /-Hylobates_pileatus
#          |         |         |                                       |                   |                             |                             |                    /2607----|
#          |         |         |                                       |                   |                             |                             |          /2606----|          \-Hylobates_lar
#          |         |         |                                       |                   |                             |                             |         |         |
#          |         |         |                                       |                   |                             |                             |         |          \-Symphalangus_syndactylus
#          |         |         |                                       |                   |                             |                             |         |
#          |         |         |                                       |                   |                             |                              \2598----|                    /-Gorilla_gorilla
#          |         |         |                                       |                   |                             |                                       |          /2601----|
#          |         |         |                                       |                   |                             |                                       |         |         |          /-Pan_troglodytes
#          |         |         |                                       |                   |                             |                                       |         |          \2605----|
#          |         |         |                                       |                   |                             |                                        \2599----|                    \-Homo_sapiens
#          |         |         |                                       |                   |                             |                                                 |
#          |         |         |                                       |                   |                             |                                                 |          /-Pongo_abelii
#          |         |         |                                       |                   |                             |                                                  \2600----|
#          |         |         |                                       |                   |                             |                                                            \-Pongo_pygmaeus
#          |         |         |                                       |                   |                             |
#          |         |         |                                       |                   |                             |                              /-Tupaia_montana
#          |         |         |                                       |                   |                             |                    /2543----|
#          |         |         |                                       |                   |                             |          /2622----|          \-Tupaia_tana
#          |         |         |                                       |                   |                             |         |         |
#          |         |         |                                       |                   |                              \2618----|          \-Tupaia_gracilis
#          |         |         |                                       |                   |                                       |
#          |         |         |                                       |                   |                                       |          /-Tupaia_belangeri
#          |         |         |                                       |                   |                                        \2620----|
#          |         |         |                                       |                   |                                                  \-Tupaia_minor
#          |         |         |                                       |                   |
#          |         |         |                                       |                   |                              /-Dasypus_novemcinctus
#          |         |         |                                       |                   |                             |
#          |         |         |                                       |                   |                             |                                        /-Tolypeutes_matacus
#          |         |         |                                       |                   |                             |                              /2541----|
#          |         |         |                                       |                   |                    /2642----|                    /2540----|          \-Cabassous_unicinctus
#          |         |         |                                       |                   |                   |         |                   |         |
#          |         |         |                                       |                   |                   |         |          /2539----|          \-Priodontes_maximus
#          |         |         |                                       |                   |                   |         |         |         |
#          |         |         |                                       |                   |                   |         |         |          \-Chlamyphorus_truncatus
#          |         |         |                                       |                   |                   |          \2637----|
#          |         |         |                                       |                   |                   |                   |                    /-Zaedyus_pichiy
#          |         |         |                                       |                   |          /2636----|                   |          /2538----|
#          |         |         |                                       |                   |         |         |                    \2530----|          \-Chaetophractus_vellerosus
#          |         |         |                                       |                   |         |         |                             |
#          |         |         |                                       |                   |         |         |                              \-Euphractus_sexcinctus
#          |         |         |                                       |                   |         |         |
#          |         |         |                                       |                   |         |         |                    /-Tamandua_tetradactyla
#          |         |         |                                       |                   |         |         |          /2645----|
#          |         |         |                                       |                   |         |         |         |          \-Myrmecophaga_tridactyla
#          |         |         |                                       |                   |         |          \2640----|
#          |         |         |                                       |                   |         |                   |          /-Choloepus_didactylus
#          |         |         |                                       |                   |         |                    \2641----|
#          |         |         |                                       |                   |         |                              \-Choloepus_hoffmanni
#          |         |         |                                       |                   |         |
#          |         |         |                                       |                    \2681----|                              /-Trichechus_manatus
#          |         |         |                                       |                             |                    /2652----|
#          |         |         |                                       |                             |                   |         |          /-Dendrohyrax_dorsalis
#          |         |         |                                       |                             |                   |          \2635----|
#          |         |         |                                       |                             |          /2634----|                    \-Procavia_capensis
#          |         |         |                                       |                             |         |         |
#          |         |         |                                       |                             |         |         |          /-Loxodonta_africana
#          |         |         |                                       |                             |         |          \2650----|
#          |         |         |                                       |                             |         |                    \-Elephas_maximus
#          |         |         |                                       |                             |         |
#          |         |         |                                       |                             |         |                              /-Potamogale_velox
#          |         |         |                                       |                             |         |                    /2655----|
#          |         |         |                                       |                             |         |                   |          \-Echinops_telfairi
#          |         |         |                                       |                              \2682----|                   |
#          |         |         |                                       |                                       |                   |                                        /-Elephantulus_edwardii
#          |         |         |                                       |                                       |                   |                              /2633----|
#          |         |         |                                       |                                       |                   |                             |          \-Elephantulus_myurus
#          |         |         |                                       |                                       |          /2658----|                    /2665----|
#          |         |         |                                       |                                       |         |         |                   |         |                    /-Elephantulus_rupestris
#          |         |         |                                       |                                       |         |         |                   |         |          /2661----|
#          |         |         |                                       |                                       |         |         |          /2659----|          \2660----|          \-Elephantulus_intufi
#          |         |         |                                       |                                       |         |         |         |         |                   |
#          |         |         |                                       |                                       |         |         |         |         |                    \-Elephantulus_brachyrhynchus
#          |         |         |                                       |                                        \2632----|          \2668----|         |
#          |         |         |                                       |                                                 |                   |          \-Rhynchocyon_chrysopygus
#          |         |         |                                       |                                                 |                   |
#          |         |         |                                       |                                                 |                   |          /-Petrodromus_tetradactylus
#          |         |         |                                       |                                                 |                    \2669----|
#          |         |         |                                       |                                                 |                              \-Macroscelides_proboscideus
#          |         |         |                                       |                                                 |
#          |         |         |                                       |                                                  \-Orycteropus_afer
#          |         |         |                                       |
#          |         |         |                                        \-Tachyglossus_aculeatus
#          |         |         |
#          |         |         |          /-Ichthyomyzon_fossor
#          |         |          \2700----|
#          |         |                   |          /-Lampetra_appendix
#          |         |                    \2692----|
#          |         |                              \-Petromyzon_marinus
#          |         |
#          |          \-Branchiostoma_floridae
#          |
#          |                    /-Pediculus_humanus
#          |          /2703----|
#           \2699----|          \-Hoplopleura_sciuricola
#                    |
#                     \-Ornithodoros_moubata

# %%
print(host_tips)
len(host_tips)
# Out:
# ['Catostomus_catostomus', 'Gila_robusta', 'Cyprinus_carpio', 'Plethodon_cinereus', 'Plethodon_shenandoah', 'Aneides_aeneus', 'Eurycea_bislineata', 'Eurycea_longicauda', 'Cornufer_guentheri', 'Mantella_aurantiaca', 'Theloderma_corticale', 'Dendrobates_tinctorius', 'Phyllobates_bicolor', 'Phyllobates_terribilis', 'Pedostibes_hosii', 'Anaxyrus_terrestris', 'Incilius_signifer', 'Atelopus_varius', 'Lepidobatrachus_laevis', 'Strabomantis_anomalus', 'Trachycephalus_resinifictrix', 'Litoria_infrafrenata', 'Hylomantis_lemur', 'Pseudechis_papuanus', 'Drymarchon_corais', 'Lampropeltis_getula', 'Lampropeltis_alterna', 'Elaphe_schrenckii', 'Nerodia_sipedon', 'Bitis_arietans', 'Crotalus_viridis', 'Bothriechis_schlegelii', 'Morelia_viridis', 'Aspidites_ramsayi', 'Python_molurus', 'Python_regius', 'Eunectes_murinus', 'Corallus_hortulanus', 'Boa_constrictor', 'Cyclura_collei', 'Iguana_iguana', 'Basiliscus_plumifrons', 'Anolis_smallwoodi', 'Anolis_allisoni', 'Anolis_barbatus', 'Uromastyx_aegyptia', 'Gonocephalus_chamaeleontinus', 'Physignathus_cocincinus', 'Pogona_vitticeps', 'Trioceros_melleri', 'Chamaeleo_calyptratus', 'Pseudopus_apodus', 'Heloderma_horridum', 'Varanus_albigularis', 'Varanus_indicus', 'Varanus_prasinus', 'Varanus_macraei', 'Varanus_olivaceus', 'Varanus_rudicollis', 'Varanus_komodoensis', 'Shinisaurus_crocodilurus', 'Dracaena_guianensis', 'Corucia_zebrata', 'Mabuya_mabouya', 'Uroplatus_fimbriatus', 'Uroplatus_lineatus', 'Eublepharis_macularius', 'Rhacodactylus_leachianus', 'Nephrurus_amyae', 'Apteryx_australis', 'Dromaius_novaehollandiae', 'Casuarius_casuarius', 'Pterocnemia_pennata', 'Rhea_americana', 'Struthio_camelus', 'Tinamus_major', 'Crypturellus_tataupa', 'Eudromia_elegans', 'Nothura_maculosa', 'Oreortyx_pictus', 'Colinus_virginianus', 'Callipepla_gambelii', 'Callipepla_californica', 'Callipepla_squamata', 'Cyrtonyx_montezumae', 'Rollulus_rouloul', 'Perdix_perdix', 'Coturnix_coturnix', 'Alectoris_graeca', 'Meleagris_gallopavo', 'Tetrastes_bonasia', 'Lyrurus_tetrix', 'Tetrao_urogallus', 'Tympanuchus_phasianellus', 'Tympanuchus_cupido', 'Dendragapus_fuliginosus', 'Dendragapus_obscurus', 'Centrocercus_urophasianus', 'Falcipennis_canadensis', 'Lagopus_lagopus', 'Lagopus_muta', 'Lagopus_leucura', 'Bonasa_umbellus', 'Pavo_cristatus', 'Argusianus_argus', 'Polyplectron_napoleonis', 'Gallus_gallus', 'Chrysolophus_pictus', 'Phasianus_colchicus', 'Tragopan_temminckii', 'Acryllium_vulturinum', 'Numida_meleagris', 'Pauxi_pauxi', 'Crax_alberti', 'Dendrocygna_viduata', 'Oxyura_jamaicensis', 'Cygnus_buccinator', 'Branta_canadensis', 'Branta_leucopsis', 'Branta_ruficollis', 'Branta_bernicla', 'Anser_anser', 'Anser_caerulescens', 'Cereopsis_novaehollandiae', 'Biziura_lobata', 'Mergus_serrator', 'Mergus_merganser', 'Lophodytes_cucullatus', 'Mergellus_albellus', 'Bucephala_albeola', 'Bucephala_clangula', 'Somateria_mollissima', 'Callonetta_leucophrys', 'Merganetta_armata', 'Histrionicus_histrionicus', 'Sarkidiornis_melanotos', 'Netta_peposaca', 'Aythya_americana', 'Aythya_collaris', 'Aythya_valisineria', 'Aythya_marila', 'Aythya_affinis', 'Aythya_fuligula', 'Hymenolaimus_malacorhynchos', 'Tachyeres_patachonicus', 'Tachyeres_pteneres', 'Amazonetta_brasiliensis', 'Speculanas_specularis', 'Mareca_strepera', 'Mareca_americana', 'Anas_acuta', 'Anas_aucklandica', 'Anas_flavirostris', 'Anas_crecca', 'Anas_platyrhynchos', 'Anas_rubripes', 'Anas_fulvigula', 'Anas_rhynchotis', 'Anas_discors', 'Clangula_hyemalis', 'Chloephaga_picta', 'Aix_galericulata', 'Aix_sponsa', 'Cairina_moschata', 'Chauna_torquata', 'Coua_cristata', 'Eudynamys_scolopaceus', 'Cacomantis_merulinus', 'Cuculus_canorus', 'Cuculus_fugax', 'Surniculus_lugubris', 'Phaenicophaeus_curvirostris', 'Coccyzus_americanus', 'Centropus_unirufus', 'Centropus_superciliosus', 'Centropus_senegalensis', 'Guira_guira', 'Crotophaga_ani', 'Crotophaga_sulcirostris', 'Geococcyx_californianus', 'Notharchus_macrorhynchos', 'Malacoptila_semicincta', 'Nystalus_maculatus', 'Colaptes_auratus', 'Dryocopus_javen ...
# 1333

# %% [markdown]
# ### Metadata

# %%
md_dir = '../data/metadata'
host_md_fp = join(md_dir, 'master_metadata_templeton_EMP_02092021.txt')
host_md = pd.read_csv(host_md_fp, sep='\t')

host_md['Taxonomy_Class'].value_counts()
# Out:
# Mammalia           57
# Aves               54
# Petromyzontida     17
# Lepidosauria        5
# Amphibia            4
# Chelonia            3
# Crocodylomorpha     2
# Name: Taxonomy_Class, dtype: int64

# %%
host_md_in_tree = host_md.loc[(host_md['TimeTree_returned'].isin(host_tips))]

# filter to just tetrapods
include_classes = ['Amphibia',
                    'Mammalia',
                    'Aves',
                    'Crocodylomorpha',
                    'Lepidosauria',
                    'Chelonia',
                  'Petromyzontida']

host_md_in_tree_with_class = host_md_in_tree.loc[host_md_in_tree['Taxonomy_Class'].isin(include_classes)]
host_md_in_tree_with_class['Taxonomy_Class'].value_counts()
# Out:
# Mammalia           54
# Aves               36
# Petromyzontida     17
# Lepidosauria        5
# Amphibia            4
# Chelonia            3
# Crocodylomorpha     2
# Name: Taxonomy_Class, dtype: int64

# %%
df_outer = host_md.merge(host_md_in_tree_with_class, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='left_only']

df_outer['TimeTree_returned'] #### Fix this stuff in the metadata so maybe these babies could be incorporated
# Out:
# 0     Giraffa_camelopardalis_reticulata
# 2             Diceros_bicornis_michaeli
# 15              Gorilla_gorilla_gorilla
# 23                   Varanus_acanthurus
# 44           Apteryx_australis_mantelli
# 63                Geospiza_acutirostris
# 65                Geospiza_acutirostris
# 67             Geospiza_septentrionalis
# 68             Geospiza_septentrionalis
# 69             Geospiza_septentrionalis
# 70             Geospiza_septentrionalis
# 71             Geospiza_septentrionalis
# 72             Geospiza_septentrionalis
# 73             Geospiza_septentrionalis
# 74             Geospiza_septentrionalis
# 75             Geospiza_septentrionalis
# 76             Geospiza_septentrionalis
# 86           Apteryx_australis_mantelli
# 87           Apteryx_australis_mantelli
# 94           Apteryx_australis_mantelli
# 95           Apteryx_australis_mantelli
# Name: TimeTree_returned, dtype: object

# %% [markdown]
# ### Microbial distance matrix

# %%
dm_dir = abspath('/projects/vertebrate_assembly/07-combined-analysis-emp500-woltka/data/core-metrics-results-low')
dm_fp = join(dm_dir, 'jaccard_distance_matrix.qza')
dm_art = Artifact.load(dm_fp)
dm = dm_art.view(skb.DistanceMatrix)

# %% [markdown]
# ### Filter metadata, dm, and tree to same samples and species

# %%
md_ids = set(host_md['sample_name'])

dm_ids = set(dm.ids)

shared_ids = dm_ids & md_ids
len(shared_ids)
# Out:
# 140

# %%
# Note that I filtered out 2 samples when processing hte dm
len(dm_ids)
# Out:
# 140

# %%
len(md_ids)
# Out:
# 142

# %%
len(shared_ids)
# Out:
# 140

# %% [markdown]
# Filter dm and metadata:

# %%
host_md_f = host_md_in_tree_with_class
host_md_f = host_md_f.loc[host_md_f['sample_name'].isin(shared_ids)]
dm = dm.filter(list(shared_ids))

# %%
host_md_f.shape
# Out:
# (120, 327)

# %%
dm.shape
# Out:
# (140, 140)

# %% [markdown]
# Prune tree:

# %%
host_tree = host_tree.shear(host_md_f['TimeTree_returned'])
host_tips = [x.name for x in host_tree.tips()]

# %%
print(host_tree.ascii_art())
# Out:
#                     /-Ichthyomyzon_fossor
#           /2700----|
#          |         |          /-Lampetra_appendix
#          |          \2692----|
#          |                    \-Petromyzon_marinus
#          |
#          |                                                  /-Uroplatus_lineatus
#          |                                        /140-----|
#          |                                       |          \-Rhacodactylus_leachianus
#          |                              /139-----|
#          |                             |         |          /-Eunectes_murinus
#          |                             |          \126-----|
#          |                             |                   |          /-Pseudopus_apodus
#          |                             |                    \127-----|
#          |                             |                              \-Varanus_albigularis
#          |                             |
#          |                             |                                                                      /-Dromaius_novaehollandiae
#          |                             |                                                            /125-----|
#          |                             |                                                  /159-----|          \-Casuarius_casuarius
#          |                             |                                                 |         |
#          |                             |                                        /158-----|          \-Rhea_americana
#          |                             |                                       |         |
#          |                             |                              /121-----|          \-Struthio_camelus
#          |                             |                             |         |
#          |                             |                             |          \-Eudromia_elegans
#          |                             |                             |
#          |                             |                             |                              /-Chrysolophus_pictus
#          |                             |                    /1659----|                    /224-----|
#          |                             |                   |         |          /311-----|          \-Acryllium_vulturinum
#          |                    /1677----|                   |         |         |         |
#          |                   |         |                   |         |         |          \-Dendrocygna_viduata
#          |                   |         |                   |         |         |
#          |                   |         |                   |         |         |                    /-Rhyticeros_undulatus
#          |                   |         |                   |          \1656----|          /1130----|
#          |                   |         |                   |                   |         |          \-Geospiza_difficilis
#          |                   |         |                   |                   |         |
#          |                   |         |                   |                   |         |                    /-Falco_biarmicus
#          |                   |         |                   |                   |         |                   |
#          |                   |         |                   |                    \1609----|          /1587----|                    /-Torgos_tracheliotos
#          |                   |         |                   |                             |         |         |          /1568----|
#          |                   |         |                   |                             |         |         |         |          \-Necrosyrtes_monachus
#          |                   |         |          /1653----|                             |         |          \1566----|
#          |                   |         |         |         |                             |         |                   |                    /-Parabuteo_unicinctus
#          |                   |         |         |         |                             |         |                   |          /1545----|
#          |                   |         |         |         |                              \1583----|                    \1572----|          \-Buteo_jamaicensis
#          |                   |         |         |         |                                       |                             |
#          |                   |         |         |         |                                       |                              \-Haliaeetus_leucocephalus
#          |                   |         |         |         |                                       |
#          |                   |         |         |         |                                       |                    /-Ardeotis_kori
# -2705----|                   |         |         |         |                                       |          /1149----|
#          |                   |          \1687----|         |                                        \1334----|          \-Grus_americana
#          |                   |                   |         |                                                 |
#          |                   |                   |         |                                                  \-Sarcoramphus_papa
#          |                   |                   |         |
#          |                   |                   |         |          /-Crocodylus_rhombifer
#          |                   |                   |          \1655----|
#          |                   |                   |                    \-Alligator_mississippiensis
#          |                   |                   |
#          |                   |                   |                    /-Astrochelys_radiata
#          |                   |                   |          /1582----|
#          |                   |                    \1666----|          \-Pyxis_arachnoides
#          |                   |                             |
#          |                   |                              \-Aldabrachelys_gigantea
#          |                   |
#          |                   |                                        /-Hypogeomys_antimena
#          |          /2678----|                                       |
#          |         |         |                              /2409----|                    /-Pteromys_volans
#          |         |         |                             |         |          /2428----|
#          |         |         |                             |          \2427----|          \-Cynomys_ludovicianus
#          |         |         |                    /2616----|                   |
#          |         |         |                   |         |                    \-Callosciurus_prevostii
#          |         |         |                   |         |
#          |         |         |                   |         |          /-Lemur_catta
#          |         |         |                   |          \2555----|
#          |         |         |                   |                    \-Mandrillus_leucophaeus
#          |         |         |                   |
#          |         |         |                   |                                                  /-Aonyx_cinerea
#          |         |         |                   |                                        /1863----|
#          |         |         |                   |                              /1866----|          \-Melursus_ursinus
#          |         |         |                   |                             |         |
#          |         |         |                   |                             |          \-Nyctereutes_procyonoides
#          |         |         |                   |                             |
#          |         |         |                   |                             |                              /-Cryptoprocta_ferox
#          |         |         |                   |                             |                             |
#          |         |         |          /2542----|                    /1862----|                    /1759----|                    /-Mungos_mungo
#          |         |         |         |         |                   |         |                   |         |          /1699----|
#          |         |         |         |         |                   |         |                   |          \1752----|          \-Suricata_suricatta
#          |         |         |         |         |                   |         |          /1763----|                   |
#          |         |         |         |         |                   |         |         |         |                    \-Helogale_parvula
#          |         |         |         |         |                   |         |         |         |
#          |         |         |         |         |                   |         |         |         |          /-Crocuta_crocuta
#          |         |         |         |         |          /1903----|          \1804----|          \1671----|
#          |         |         |         |         |         |         |                   |                   |          /-Hyaena_hyaena
#          |         |         |         |         |         |         |                   |                    \1673----|
#          |         |         |         |         |         |         |                   |                              \-Parahyaena_brunnea
#          |         |         |         |         |         |         |                   |
#          |         |         |         |         |         |         |                    \-Felis_margarita
#           \2694----|         |         |         |         |         |
#                    |         |         |         |         |         |          /-Equus_przewalskii
#                    |         |         |         |         |          \1891----|
#                    |         |         |          \2277----|                    \-Equus_burchellii
#                    |          \2680----|                   |
#                    |                   |                   |                                                  /-Carollia_sowelli
#                    |                   |                   |                                        /2105----|
#                    |                   |                   |                              /2137----|          \-Carollia_perspicillata
#                    |                   |                   |                             |         |
#                    |                   |                   |                    /2169----|          \-Artibeus_intermedius
#                    |                   |                   |                   |         |
#                    |                   |                   |          /2192----|          \-Glossophaga_morenoi
#                    |                   |                   |         |         |
#                    |                   |                    \2278----|          \-Desmodus_rotundus
#                    |                   |                             |
#                    |                   |                              \-Balantiopteryx_plicata
#                    |                   |
#                    |                   |                    /-Tolypeutes_matacus
#                    |                   |          /2636----|
#                    |                   |         |         |          /-Tamandua_tetradactyla
#                    |                   |         |          \2645----|
#                    |                    \2681----|                    \-Myrmecophaga_tridactyla
#                    |                             |
#                    |                             |                    /-Trichechus_manatus
#                    |                             |          /2634----|
#                    |                              \2682----|          \-Loxodonta_africana
#                    |                                       |
#                    |                                        \-Echinops_telfairi
#                    |
#                    |                              /-Lepidobatrachus_laevis
#                    |                    /42------|
#                    |          /47------|          \-Pedostibes_hosii
#                    |         |         |
#                     \39------|          \-Trachycephalus_resinifictrix
#                              |
#                               \-Cornufer_guentheri

# %% [markdown]
# ## Test: overall mantel

# %% [markdown]
# First, we'll subset the host tree. For testing purposes, we can set subset to `True` to pull 100 random host species.

# %%
# Note if subset is false we are not testing but running the overall mantel
subset = False

# %%
#Reset host_md_f to host_md
host_md = host_md_f

# %%
# subset the tree if desired
if subset:
    host_subset = np.random.choice(host_tips, size=100, replace=False)
else:
    host_subset = host_tips

host_tree_subset = host_tree.shear(host_subset)

host_ids_subset = host_md.loc[host_md['TimeTree_returned'].isin(host_subset), 'sample_name']

# %%
len(host_ids_subset)
# Out:
# 120

# %% [markdown]
# Within-species comparisons can artificially inflate the signal of 'phylosymbiosis' because they tend to be more similar for a host of reasons, and have a branch length of 0. Since we only care about between-species comparisons, we will subset to a single arbitrarily-chosen individual per species (if `one_per_sp == True`).

# %%
one_per_sp = True

# %%
if one_per_sp:
    host_md = host_md.loc[(host_md['sample_name'].isin(host_ids_subset)) &
                          (host_md['sample_name'].isin(dm.ids)),].groupby('TimeTree_returned').first()
    host_md =  host_md.loc[(host_md['sample_name'].isin(host_ids_subset)) &
                          (host_md['sample_name'].isin(dm.ids)),].groupby('TimeTree_returned').first().reset_index()
    host_ids_subset = list(set(host_ids_subset) & set(host_md['sample_name']))

# %%
len(host_ids_subset)
# Out:
# 67

# %%
host_ids_subset
# Out:
# ['13114.song.53.s009',
#  '11166.ATL.24564.meerkat',
#  '11166.ATL.24545.hawk',
#  '11166.UM.24898.finch',
#  '13114.song.75.s002',
#  '13114.song.51.s015',
#  '13114.song.51.s014',
#  '11166.lamprey.24146.lamprey',
#  '11166.FD.0126.hyena',
#  '13114.song.51.s013',
#  '2338.0620.8.I',
#  '13114.song.51.s002',
#  '11166.FD.0441.tinamou',
#  '2338.0623.7.I',
#  '11166.FD.0437.hyena',
#  '13114.song.53.s007',
#  '13114.song.53.s006',
#  '11166.ATL.24487.vulture',
#  '11166.AR.M18.flyingsquirrel',
#  '11166.ATL.24553.hawk',
#  '13114.song.53.s008',
#  '11166.FD.0122.hyena',
#  '11166.vbat.DR07.colon.vbat',
#  '13114.song.51.s008',
#  '13114.song.51.s009',
#  '13114.song.52.s007',
#  '11166.vbat.K3.colon.bat',
#  '13114.song.51.s012',
#  '13114.song.53.s010',
#  '11166.ATL.25136.fossa',
#  '11166.ATL.24614.prairiedog',
#  '13114.song.53.s012',
#  '13114.song.53.s001',
#  '13114.song.51.s020',
#  '13114.song.51.s006',
#  '11166.lamprey.24159.lamprey',
#  '13114.song.51.s004',
#  '13114.song.52.s013',
#  '11166.ATL.24548.falcon',
#  '13114.song.52.s008',
#  '13114.song.75.s003',
#  '13114.song.51.s007',
#  '11166.lamprey.24144.lamprey',
#  '13114.song.52.s004',
#  '13114.song.52.s009',
#  '13114.song.51.s017',
#  '13114.song.52.s006',
#  '11166.ATL.24483.eagle',
#  '11166.ATL.24572.vulture',
#  '13114.song.51.s005',
#  '11166.vbat.K1.colon.bat',
#  '13114.song.52.s014',
#  '13114.song.53.s002',
#  '2338.0624.6.I',
#  '13114.song.52.s001',
#  '13114.song.51.s011',
#  '13114.song.53.s005',
#  '13114.song.53.s014',
#  '13114.song.52.s011',
#  '13114.song.52.s002',
#  '13114.song.52.s015',
#  '13114.song.52.s003',
#  '13114.song.53.s003',
#  '13114.song.52.s012',
#  '13114.song.51.s018',
#  '13114.song.51.s010',
#  '13114.song.52.s010']

# %% [markdown]
# ### Calculate patristic distances

# %%
patristic_dm = host_tree_subset.tip_tip_distances()

# %%
patristic_dm.shape
# Out:
# (67, 67)

# %% [markdown]
# ### Add diet distances

# %%
elton_cols = ['ET.Diet.Fruit',
             'ET.Diet.Inv',
             'ET.Diet.Nect',
             'ET.Diet.PlantO',
             'ET.Diet.Scav',
             'ET.Diet.Seed',
             'ET.Diet.Vect',
             'ET.Diet.Vend',
             'ET.Diet.Vfish',
             'ET.Diet.Vunk']

# %%
host_diet_df = host_md.loc[host_md[elton_cols].sum(axis=1) == 100,
                           ['sample_name'] + elton_cols].dropna()

# %%
host_diet_df.set_index('sample_name', inplace=True)

# %%
host_diet_df
# Out:
#                              ET.Diet.Fruit  ET.Diet.Inv  ET.Diet.Nect  \
# sample_name
# 13114.song.53.s012                    20.0         10.0           0.0
# 13114.song.75.s002                     0.0         80.0           0.0
# 13114.song.53.s005                    20.0         20.0           0.0
# 2338.0623.7.I                         80.0         10.0          10.0
# 11166.vbat.K3.colon.bat                0.0        100.0           0.0
# 11166.ATL.24545.hawk                   0.0         10.0           0.0
# 13114.song.51.s013                    20.0         20.0           0.0
# 2338.0620.8.I                        100.0          0.0           0.0
# 2338.0624.6.I                        100.0          0.0           0.0
# 13114.song.53.s006                    80.0         10.0           0.0
# 13114.song.53.s003                     0.0         10.0           0.0
# 11166.FD.0437.hyena                    0.0          0.0           0.0
# 11166.ATL.25136.fossa                  0.0         10.0           0.0
# 11166.ATL.24614.prairiedog             0.0          0.0           0.0
# 13114.song.53.s009                    10.0         30.0           0.0
# 11166.vbat.DR07.colon.vbat             0.0          0.0           0.0
# 13114.song.53.s007                    30.0         20.0           0.0
# (50, 10)

# %%
# Loc a missing label is no longer supported --> host_diet_df = host_diet_df.loc[host_ids_subset,:].dropna()
host_diet_df=host_diet_df.loc[host_diet_df.index.intersection(host_ids_subset)]

# %%
host_diet_df.head()
# Out:
#                          ET.Diet.Fruit  ET.Diet.Inv  ET.Diet.Nect  \
# 13114.song.53.s012                20.0         10.0           0.0
# 13114.song.75.s002                 0.0         80.0           0.0
# 13114.song.53.s005                20.0         20.0           0.0
# 2338.0623.7.I                     80.0         10.0          10.0
# 11166.vbat.K3.colon.bat            0.0        100.0           0.0
#
#                          ET.Diet.PlantO  ET.Diet.Scav  ET.Diet.Seed  \
# 13114.song.53.s012                 50.0           0.0          20.0
# 13114.song.75.s002                  0.0           0.0           0.0
# 13114.song.53.s005                 20.0           0.0          20.0
# 2338.0623.7.I                       0.0           0.0           0.0
# 11166.vbat.K3.colon.bat             0.0           0.0           0.0
#
#                          ET.Diet.Vect  ET.Diet.Vend  ET.Diet.Vfish  \
# 13114.song.53.s012                0.0           0.0            0.0
# 13114.song.75.s002               10.0           0.0           10.0
# 13114.song.53.s005               10.0          10.0            0.0
# 2338.0623.7.I                     0.0           0.0            0.0
# 11166.vbat.K3.colon.bat           0.0           0.0            0.0
#
#                          ET.Diet.Vunk
# 13114.song.53.s012                0.0
# 13114.song.75.s002                0.0
# 13114.song.53.s005                0.0
# 2338.0623.7.I                     0.0
# 11166.vbat.K3.colon.bat           0.0

# %%
diet_dm = skb.DistanceMatrix(squareform(pdist(host_diet_df.iloc[:, :], metric='braycurtis')))
diet_dm.ids = host_diet_df.index

# %%
diet_dm.shape
# Out:
# (50, 50)

# %%
rename_df = host_md.loc[host_md['sample_name'].isin(diet_dm.ids),
                             ['sample_name','TimeTree_returned']].set_index('sample_name')
rename = [rename_df.loc[x, 'TimeTree_returned'] for x in diet_dm.ids]

# %%
diet_dm.ids = rename

# %% [markdown]
# ### Subset DM to remaining hosts and rename by tree

# %%
dm_subset = dm.filter(list(host_ids_subset))

# %%
dm_subset.shape
# Out:
# (67, 67)

# %%
rename_df = host_md.loc[host_md['sample_name'].isin(dm_subset.ids),
                             ['sample_name','TimeTree_returned']].set_index('sample_name')
rename = [rename_df.loc[x, 'TimeTree_returned'] for x in dm_subset.ids]

# %%
dm_subset.ids = rename

# %%
set(dm_subset.ids) == set(patristic_dm.ids)
# Out:
# True

# %% [markdown]
# # Method to run mantel iteratively across tree

# %%
def recursive_mantel(tree, dm1, dm2, min_size=7, **kwargs):
    i = 0
    nodes = tree.count(tips=True) * 2 - 1
    tree.assign_ids()
    node_dict = {}
    for n in tree.postorder():
        label = n.name
        i += 1
        # see if you're below minimum clade size
        if n.count(tips=True) < min_size:
            continue
        # if not, run mantel
        else:
            tips = [t.name for t in n.tips()]
            dm1_s = dm1.filter(tips)
            dm2_s = dm2.filter(tips)
            corr, p, _ = mantel(dm1_s, dm2_s, **kwargs)
            node_dict[n.name] = (corr, p)
    
        pct = (i / nodes)
        
        if np.round(pct * 100) % 10 == 0:
            print(pct)
    return(node_dict)

# %%
def recursive_mantel_ecopy(tree, dm1, dm2, min_size=7, **kwargs):
    i = 0
    nodes = tree.count(tips=True) * 2 - 1
    tree.assign_ids()
    node_dict = {}
    for n in tree.postorder():
        label = n.name
        i += 1
        # see if you're below minimum clade size
        if n.count(tips=True) < min_size:
            continue
        # if not, run mantel
        else:
            tips = [t.name for t in n.tips()]
            dm1_s = dm1.filter(tips)
            dm2_s = dm2.filter(tips)
            res = Mantel(dm1_s.data, dm2_s.data, **kwargs)
            
            node_dict[n.name] = (res.r_obs, res.pval)
    
        pct = (i / nodes)
        
        if np.round(pct * 100) % 10 == 0:
            print(pct)
    return(node_dict)

# %%
def recursive_partial_mantel_ecopy(tree, dm1, dm2, dmc, min_size=7, **kwargs):
    i = 0
    nodes = tree.count(tips=True) * 2 - 1
    tree.assign_ids()
    node_dict = {}
    for n in tree.postorder():
        label = n.name
        i += 1
        # see if you're below minimum clade size
        if n.count(tips=True) < min_size:
            continue
        # if not, run mantel
        else:
            tips = [t.name for t in n.tips()]
            dm1_s = dm1.filter(tips)
            dm2_s = dm2.filter(tips)
            dmc_s = dmc.filter(tips)
            res = Mantel(dm1_s.data, dm2_s.data, d_condition=dmc_s.data, **kwargs)
            
            node_dict[n.name] = (res.r_obs, res.pval)
    
        pct = (i / nodes)
        
        if np.round(pct * 100) % 10 == 0:
            print(pct)
    return(node_dict)

# %%
# assign internal node names, non-integer

host_tree_subset.assign_ids()

for n in host_tree_subset.postorder():
    if n.is_tip():
        continue
    elif n.name[0].isdigit(): 
        n.name = "node%s" % n.name

# %%
tips = set(patristic_dm.ids) & set(dm_subset.ids) & set(diet_dm.ids)

# %%
len(tips)
# Out:
# 50

# %% [markdown]
# Change `run` to `True` if re-calculating values

# %%
run = True

# %%
if run:
    node_dict_spearman = recursive_mantel(host_tree_subset, patristic_dm, dm_subset, method='spearman')
# Out:
# 0.6992481203007519
# 1.0

# %%
if run:
    node_dict_pearson = recursive_mantel(host_tree_subset, patristic_dm, dm_subset, method='pearson')
# Out:
# 0.6992481203007519
# 1.0

# %% [markdown]
# ### Run partial Mantel tests, conditioned on diet

# %%
if run:
    node_dict_spearman_partial = recursive_partial_mantel_ecopy(host_tree_subset.shear(tips),
                                      patristic_dm.filter(tips),
                                      dm_subset.filter(tips),
                                      diet_dm.filter(tips),
                                      test='spearman')
# Out:
# /home/jhc103/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/ecopy/matrix_comp/mantel.py:193: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   params = np.linalg.lstsq(Z, y_flat)[0]
# 1.0

# %%
if run:
    node_dict_pearson_partial = recursive_partial_mantel_ecopy(host_tree_subset.shear(tips),
                                      patristic_dm.filter(tips),
                                      dm_subset.filter(tips),
                                      diet_dm.filter(tips),
                                      test='pearson')
# Out:
# 1.0

# %% [markdown]
# ## Write to file

# %%
out_dir = '../data/phylosymbiosis/mantel'

# %%
makedirs(out_dir, exist_ok=True)

# %%
if run:
    host_tree_subset.write(join(out_dir,'annotated_host_tree.tre'), format='newick')

# %%
if run:
    node_df_pearson = pd.DataFrame.from_dict(node_dict_pearson, orient='index')
    node_df_pearson.columns = ['r','p']
    node_df_pearson.to_csv(join(out_dir, 'mantel.jaccard.pearson.csv'))

# %%
if run:
    node_df_spearman =  pd.DataFrame.from_dict(node_dict_spearman, orient='index')
    node_df_spearman.columns = ['r','p']
    node_df_spearman.to_csv(join(out_dir, 'mantel.jaccard.spearman.csv'))

# %%
if run:
    node_df_pearson_partial = pd.DataFrame.from_dict(node_dict_pearson_partial, orient='index')
    node_df_pearson_partial.columns = ['r','p']
    node_df_pearson_partial.to_csv(join(out_dir, 'mantel_partial.jaccard.pearson.csv'))

# %%
if run:
    node_df_spearman_partial =  pd.DataFrame.from_dict(node_dict_spearman_partial, orient='index')
    node_df_spearman_partial.columns = ['r','p']
    node_df_spearman_partial.to_csv(join(out_dir, 'mantel_partial.jaccard.spearman.csv'))

# %% [markdown]
# ## Calculate values for particular nodes

# %%
host_tree_subset = TreeNode.read(join(out_dir,'annotated_host_tree.tre'))

# %%
node_df_pearson = pd.read_csv(join(out_dir, 'mantel.jaccard.pearson.csv'), index_col=0)
node_df_spearman = pd.read_csv(join(out_dir, 'mantel.jaccard.spearman.csv'), index_col=0)
node_df_pearson_partial = pd.read_csv(join(out_dir, 'mantel_partial.jaccard.pearson.csv'), index_col=0)
node_df_spearman_partial = pd.read_csv(join(out_dir, 'mantel_partial.jaccard.spearman.csv'), index_col=0)

# %%
def node_values(tips, tree, node_df, tree_dm, dist_dm):
    node_name = tree.lca(tips).name
    
    r = node_df_pearson.loc[node_name, 'r']
    p = node_df_pearson.loc[node_name, 'p']
    
    pats = patristic_dm.filter(tips)
    dsts = dm_subset.filter(tips)

    x = pats.to_series()
    y = dsts.to_series()

    slope, _, _, _, _ = linregress(x, y)
    
    plot = sns.lmplot('x',
                      'y',
                      pd.DataFrame({'x': x, 'y': y}).reset_index(),
                      scatter_kws={'alpha':0.1})
    plt.ylim(0.5, 1.05)

    print(("r: {r}\n"
       "p: {p}\n"
       "m: {m:8.7f}\n").format(r=r, p=p, m=slope))
    
#     plot

# %%
# Look at our Taxonomy_Class & Taxonomy_Order
host_md['Taxonomy_Class'].value_counts()
host_md['Taxonomy_Order'].value_counts() ## <-- this isn't populated which could help with more analysis
# Out:
# Carnivora             11
# Falconiformes          6
# Chiroptera             6
# Squamata               5
# Rodentia               4
# Anura                  4
# Petromyzontiformes     3
# Testudines             3
# Gruiformes             2
# Perissodactyla         2
# Pilosa                 2
# Galliformes            2
# Primates               2
# Crocodylia             2
# Casuariiformes         2
# Struthioniformes       1
# Anseriformes           1
# Proboscidea            1
# Ciconiiformes          1
# Rheiformes             1
# Cingulata              1
# Sirenia                1
# Passeriformes          1
# Afrosoricida           1
# Tinamiformes           1
# Bucerotiformes         1
# Name: Taxonomy_Order, dtype: int64

# %% [markdown]
# ### Mammals

# %%
tips = set(host_md.loc[host_md['Taxonomy_Class'] == 'Mammalia','TimeTree_returned']) & set(host_subset)

node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
# Out:
# /home/jhc103/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# r: 0.09461956325620137
# p: 0.316
# m: 0.0001916

# %% [markdown]
# ### Birds

# %%
tips = set(host_md.loc[host_md['Taxonomy_Class'] == 'Aves','TimeTree_returned']) & set(host_subset)

node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
# Out:
# /home/jhc103/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# r: 0.2664142858248233
# p: 0.004
# m: 0.0003278

# %% [markdown]
# ### Bats

# %%
tips = set(host_md.loc[host_md['Taxonomy_Order'] == 'Chiroptera',
                       'TimeTree_returned']) & set(host_subset)

node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'node2278'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-2f8ab7e0959b> in <module>
#       2                        'TimeTree_returned']) & set(host_subset)
#       3
# ----> 4 node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
#
# <ipython-input-78-14c8273285bc> in node_values(tips, tree, node_df, tree_dm, dist_dm)
#       2     node_name = tree.lca(tips).name
#       3
# ----> 4     r = node_df_pearson.loc[node_name, 'r']
#       5     p = node_df_pearson.loc[node_name, 'p']
#       6
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     784                 # We don't need to check for tuples here because those are
#     785                 #  caught by the _is_nested_tuple_indexer check above.
# --> 786                 section = self._getitem_axis(key, axis=i)
#     787
#     788                 # We should never have a scalar section here, because
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3491             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3492         else:
# -> 3493             loc = self.index.get_loc(key)
#    3494
#    3495             if isinstance(loc, np.ndarray):
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'node2278'

# %% [markdown]
# ### Cetartiodactyla

# %%
tips = set(host_md.loc[host_md['Taxonomy_Order'] == 'Cetartiodactyla',
                       'TimeTree_returned']) & set(host_subset)

node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-293202c1aa6e> in <module>
#       2                        'TimeTree_returned']) & set(host_subset)
#       3
# ----> 4 node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
#
# <ipython-input-78-14c8273285bc> in node_values(tips, tree, node_df, tree_dm, dist_dm)
#       1 def node_values(tips, tree, node_df, tree_dm, dist_dm):
# ----> 2     node_name = tree.lca(tips).name
#       3
#       4     r = node_df_pearson.loc[node_name, 'r']
#       5     p = node_df_pearson.loc[node_name, 'p']
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/skbio/tree/_tree.py in lowest_common_ancestor(self, tipnames)
#    1808
#    1809         if len(tips) == 0:
# -> 1810             raise ValueError("No tips found.")
#    1811
#    1812         nodes_to_scrub = []
#
# ValueError: No tips found.

# %% [markdown]
# ### Perissodactyla

# %%
tips = set(host_md.loc[host_md['Taxonomy_Order'] == 'Perissodactyla',
                       'TimeTree_returned']) & set(host_subset)

node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'node1891'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-bb3074e7a782> in <module>
#       2                        'TimeTree_returned']) & set(host_subset)
#       3
# ----> 4 node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
#
# <ipython-input-78-14c8273285bc> in node_values(tips, tree, node_df, tree_dm, dist_dm)
#       2     node_name = tree.lca(tips).name
#       3
# ----> 4     r = node_df_pearson.loc[node_name, 'r']
#       5     p = node_df_pearson.loc[node_name, 'p']
#       6
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     784                 # We don't need to check for tuples here because those are
#     785                 #  caught by the _is_nested_tuple_indexer check above.
# --> 786                 section = self._getitem_axis(key, axis=i)
#     787
#     788                 # We should never have a scalar section here, because
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3491             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3492         else:
# -> 3493             loc = self.index.get_loc(key)
#    3494
#    3495             if isinstance(loc, np.ndarray):
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'node1891'

# %% [markdown]
# ### Primates

# %%
tips = set(host_md.loc[host_md['Taxonomy_Order'] == 'Primates',
                       'TimeTree_returned']) & set(host_subset)

node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'node2555'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-d371f99ba74f> in <module>
#       2                        'TimeTree_returned']) & set(host_subset)
#       3
# ----> 4 node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
#
# <ipython-input-78-14c8273285bc> in node_values(tips, tree, node_df, tree_dm, dist_dm)
#       2     node_name = tree.lca(tips).name
#       3
# ----> 4     r = node_df_pearson.loc[node_name, 'r']
#       5     p = node_df_pearson.loc[node_name, 'p']
#       6
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     784                 # We don't need to check for tuples here because those are
#     785                 #  caught by the _is_nested_tuple_indexer check above.
# --> 786                 section = self._getitem_axis(key, axis=i)
#     787
#     788                 # We should never have a scalar section here, because
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3491             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3492         else:
# -> 3493             loc = self.index.get_loc(key)
#    3494
#    3495             if isinstance(loc, np.ndarray):
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'node2555'

# %% [markdown]
# ### Carnivora

# %%
tips = set(host_md.loc[host_md['Taxonomy_Order'] == 'Carnivora',
                       'TimeTree_returned']) & set(host_subset)

node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
# Out:
# /home/jhc103/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# r: 0.2257939623845374
# p: 0.221
# m: 0.0009900

# %% [markdown]
# ### Rodentia

# %%
tips = set(host_md.loc[host_md['Taxonomy_Order'] == 'Rodentia',
                       'TimeTree_returned']) & set(host_subset)

node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'node2409'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-43b1c5c8f32e> in <module>
#       2                        'TimeTree_returned']) & set(host_subset)
#       3
# ----> 4 node_values(tips, host_tree_subset, node_df_pearson, patristic_dm, dm_subset)
#
# <ipython-input-78-14c8273285bc> in node_values(tips, tree, node_df, tree_dm, dist_dm)
#       2     node_name = tree.lca(tips).name
#       3
# ----> 4     r = node_df_pearson.loc[node_name, 'r']
#       5     p = node_df_pearson.loc[node_name, 'p']
#       6
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     784                 # We don't need to check for tuples here because those are
#     785                 #  caught by the _is_nested_tuple_indexer check above.
# --> 786                 section = self._getitem_axis(key, axis=i)
#     787
#     788                 # We should never have a scalar section here, because
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3491             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3492         else:
# -> 3493             loc = self.index.get_loc(key)
#    3494
#    3495             if isinstance(loc, np.ndarray):
#
# ~/miniconda3/envs/ecopy-qiime2-py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'node2409'

# %% [markdown]
# # Write tree color file

# %%
itol_dir = '../phylosymbiosis/itol'

# %%
makedirs(itol_dir, exist_ok=True)

# %%
import matplotlib as mpl

# %%
node_df_pearson['r'].max()

# %%
node_df_spearman['r'].max()

# %%
node_df_pearson_partial['r'].max()

# %%
node_df_spearman_partial['r'].max()

# %%
# create dummy invisible image
# (use the colormap you want to have on the colorbar)
cmax = node_df_pearson['r'].max()
img = plt.imshow(np.array([[0,cmax]]), cmap=mpl.cm.plasma)
img.set_visible(False)

plt.colorbar(orientation="vertical")

# add any other things you want to the figure.
# plt.plot(np.random.rand(30))

# %%
def colorbar(fp,
             cmax=1,
             size=(4,.7)):
    a = np.array([[0,cmax]])
    pl.figure(figsize=size)
    img = pl.imshow(a, cmap=mpl.cm.plasma)
    pl.gca().set_visible(False)
    cax = pl.axes([0.1, 0.4, 0.8, 0.5])
    pl.colorbar(orientation='horizontal', cax=cax)
    pl.savefig(fp)

# %%
colorbar(join(itol_dir, 'mantel.jaccard.pearson.itol-r_colorbar.pdf'),
         cmax=node_df_pearson['r'].max(),
         size=(2.5,.6))

# %%
colorbar(join(itol_dir, 'mantel.jaccard.spearman.itol-r_colorbar.pdf'),
         cmax=node_df_spearman['r'].max(),
         size=(2.5,.6))

# %%
colorbar(join(itol_dir, 'mantel_partial.jaccard.pearson.itol-r_colorbar.pdf'),
         cmax=node_df_pearson_partial['r'].max(),
         size=(2.5,.6))

# %%
colorbar(join(itol_dir, 'mantel_partial.jaccard.spearman.itol-r_colorbar.pdf'),
         cmax=node_df_spearman_partial['r'].max(),
         size=(2.5,.6))

# %%
def get_colors(vals, col, cmap=mpl.cm.plasma):
    norm = mpl.colors.Normalize(vmin=0, vmax=np.max(vals))
    
    colors = []
    
    for i in vals:
        rgb = mpl.cm.ScalarMappable(norm=norm,
                                    cmap=cmap).to_rgba(i)
        hex_val = mpl.colors.rgb2hex(rgb)
        colors.append(hex_val)

    return(colors)

def write_itol_colors(node_df, col, fp, label='branch_colors'):
    out = ('DATASET_STYLE\n\n'
           'SEPARATOR SPACE\n\n'
           'COLOR #ffff00\n\n'
           'DATASET_LABEL %s\n\n'
           'DATA\n'
           '#NODE_ID TYPE COLOR LABEL_OR_STYLE SIZE_FACTOR\n' % label)

    for i, row in node_df.iterrows():
        out += '{0} branch node {1} 2 normal\n'.format(i, row[col])

    with open(fp, 'w') as f:
        f.write(out)

# %%
#LEGEND_TITLE,Dataset legend
#LEGEND_SHAPES,1,2,3
#LEGEND_COLORS,#ff0000,#00ff00,#0000ff
#LEGEND_LABELS,value1,value2,value3

# %%
node_df_pearson['r_color'] = get_colors(node_df_pearson['r'], col='r')
node_df_spearman['r_color'] = get_colors(node_df_spearman['r'], col='r')

# %%
node_df_pearson_partial['r_color'] = get_colors(node_df_pearson_partial['r'], col='r')
node_df_spearman_partial['r_color'] = get_colors(node_df_spearman_partial['r'], col='r')

# %%
write_itol_colors(node_df_pearson, 
                  'r_color', 
                  join(itol_dir, 'mantel.jaccard.pearson.itol-r_colors.txt'),
                  label='pearson_r')
write_itol_colors(node_df_spearman, 
                  'r_color',
                  join(itol_dir, 'mantel.jaccard.spearman.itol-r_colors.txt'),
                  label='spearman_r')

# %%
write_itol_colors(node_df_pearson_partial, 
                  'r_color', 
                  join(itol_dir, 'mantel_partial.jaccard.pearson.itol-r_colors.txt'),
                  label='pearson_r_partial')
write_itol_colors(node_df_spearman_partial, 
                  'r_color',
                  join(itol_dir, 'mantel_partial.jaccard.spearman.itol-r_colors.txt'),
                  label='spearman_r_partial')

# %% [markdown]
# ### Write pie chart p-val indicator file

# %%
# 9132,0,50,11000
def write_pval_pies(node_df, col, fp, label='p-vals', breaks = [0.001, 0.01, 0.05]):
    header = ("DATASET_PIECHART\n"
              "SEPARATOR SPACE\n"
              "DATASET_LABEL %s\n"
              "COLOR #ff0000\n"
              "FIELD_COLORS #ff0000\n"
              "FIELD_LABELS p-value\n"
              "MAXIMUM_SIZE 30\n"
              "BORDER_WIDTH 0\n"
              "DATA\n" % label)
    
    break_sizes = [int(30 - i/len(breaks)*30) for i, x in enumerate(breaks)]
    pies = []
    for i, row in node_df.iterrows():
        size = 0
        for s, b in enumerate(breaks):
            if row[col] > b:
                continue
            else:
                size = break_sizes[s]
                break
        if size > 0:
            pies.append("{0} 0 {1} 1".format(i, size))
    
    out = header + '\n'.join(pies)
    
    with open(fp, 'w') as f:
        f.write(out)

# %%
write_pval_pies(node_df_pearson, 
                'p', 
                join(itol_dir, 'mantel.jaccard.pearson.itol-p_pies.txt'), 
                label='pearson_p')
write_pval_pies(node_df_spearman, 
                'p', 
                join(itol_dir, 'mantel.jaccard.spearman.itol-p_pies.txt'),
                label='spearman_p')

# %%
write_pval_pies(node_df_pearson_partial, 
                'p',
                join(itol_dir, 'mantel_partial.jaccard.pearson.itol-p_pies.txt'),
                label='pearson_p_partial')
write_pval_pies(node_df_spearman_partial, 
                'p',
                join(itol_dir, 'mantel_partial.jaccard.spearman.itol-p_pies.txt'),
                label='spearman_p_partial')

# %% [markdown]
# ### Write clade highlighting

# %%
def write_clade_highlights(md_df, tree, tax_col, tree_col, fp,
                           label='clade_highlights',
                           colors=None, alpha=0.4, cmap=mpl.cm.Set3):
    out = ('DATASET_COLORSTRIP\n\n'
           'SEPARATOR SPACE\n\n'
           'COLOR #b2df8a\n\n'
           'DATASET_LABEL %s\n\n'% label)
    
    taxa = md_df[tax_col].unique()
    
    if colors is None:
        clist = cmap(range(len(taxa)), alpha=alpha)
        rgblist = ['rgba(%s,%s,%s,%s)' % (int(x[0]*255),
                                          int(x[1]*255),
                                          int(x[2]*255),
                                          x[3]) for x in clist]
        colors = {x: rgblist[i] for i, x in enumerate(taxa)}
    
    legend_shapes = ' '.join(['1']*len(taxa))
    legend_colors = ''
    legend_labels = ''
    
    for x in colors:
        legend_colors += ' %s' % colors[x]
        legend_labels += ' %s' % x
    
    out += ('LEGEND_TITLE host_colors\n'
            'LEGEND_SHAPES {0}\n'
            'LEGEND_COLORS{1}\n'
            'LEGEND_LABELS{2}\n\nDATA\n').format(legend_shapes,
                                            legend_colors,
                                            legend_labels)
        
    for taxon in taxa:
        tips = set(md_df.loc[md_df[tax_col] == taxon, tree_col])
        node = tree.lowest_common_ancestor(tips)
        
        out += "{0} {1}\n".format(node.name, colors[taxon])
#         out += "{0} range {1} {2}\n".format(node.name, colors[taxon], taxon)
        
    with open(fp, 'w') as f:
        f.write(out)

# %%
class_colors = {'Amphibia': '#b2df8a',
                 'Chelonia': '#33a02c',
                 'Lepidosauria': '#fb9a99',
                 'Crocodylomorpha': '#e31a1c',
                 'Aves': '#EACB47',
                 'Mammalia': '#6a3d9a'}

write_clade_highlights(host_md, 
                       host_tree_subset, 
                       'Taxonomy_Class', 
                       'TimeTree_returned',
                       join(itol_dir, 'mantel.itol-Class_colors.txt'),
                       colors=class_colors)

# %%
# !head -n 20 ../phylosymbiosis/itol/mantel.itol-Class_colors.txt

# %% [markdown]
# ### Write flight annotations

# %%
def write_binary_colorstrip(md_df, col, tree_col, fp,
                           label='categorical_colorstrip',
                           colors=None, alpha=1, cmap=mpl.cm.Set3):
    out = ('DATASET_COLORSTRIP\n\n'
           'SEPARATOR SPACE\n\n'
           'COLOR #8ab2df\n\n'
           'DATASET_LABEL %s\n\n'% label)
    
    values = md_df[col].unique()
    
    if colors is None:
        clist = cmap(range(len(values)), alpha=alpha)
        rgblist = ['rgba(%s,%s,%s,%s)' % (int(x[0]*255),
                                          int(x[1]*255),
                                          int(x[2]*255),
                                          x[3]) for x in clist]
        colors = {x: rgblist[i] for i, x in enumerate(values)}
    
    legend_shapes = ' '.join(['1']*len(values))
    legend_colors = ''
    legend_labels = ''
    
    for x in colors:
        legend_colors += ' %s' % colors[x]
        legend_labels += ' %s' % x
    
    out += ('LEGEND_TITLE {0}\n'
            'LEGEND_SHAPES {1}\n'
            'LEGEND_COLORS{2}\n'
            'LEGEND_LABELS{3}\n\nDATA\n').format(label,
                                            legend_shapes,
                                            legend_colors,
                                            legend_labels)
        
    for taxon in md_df[tree_col]:
        
        out += "{0} {1}\n".format(taxon, colors[md_df.loc[md_df[tree_col] == taxon,
                                                          col].values[0]])
    
    with open(fp, 'w') as f:
        f.write(out)

# %%
flight_colors = {'flighted': '#000000',
                 'flightless': '#FFFFFF'}

write_binary_colorstrip(host_md, 
                        'flight_status', 
                        'TimeTree_returned', 
                        join(itol_dir, 'mantel.itol-flight_colors.txt'),
                        colors=flight_colors)

# %% [markdown]
# ### Write diet barcharts

# %%
def get_qualitative_colors(fields, cmap=mpl.cm.Set3, alpha=0.4):
    clist = cmap(range(len(taxa)), alpha=alpha)
    rgblist = ['rgba(%s,%s,%s,%s)' % (int(x[0]*255),
                                      int(x[1]*255),
                                      int(x[2]*255),
                                      x[3]) for x in clist]
    return(rgblist)

def format_iTOL_multibar(fields, md, 
                         tree_ref_col=None, 
                         field_colors=None, 
                         field_labels=None, 
                         dataset_label='Multibar Chart', 
                         dataset_color=None, 
                         legend=True, 
                         unstacked=False,
                         width=1000, 
                         margin=0,
                         alpha=0.8,
                        ):
    """
    fields: array of columns titles in [metadata] to chart
    metadata: pd.df containing samples to graph and data
    """
    
    if field_labels is None:
        field_labels=fields
    
    if field_colors is None:
        field_colors=get_qualitative_colors(fields, alpha=alpha)
    
    if tree_ref_col is None:
        tree_ref_col=metadata.columns[0]

    if dataset_color is None:
        dataset_color = "#00FF00"

    # remove nans
    metadata = md.loc[:,fields + [tree_ref_col]].dropna()
    
    outstring = ''
    
    outstring += 'DATASET_MULTIBAR\n'
    outstring += 'SEPARATOR TAB\n'
    outstring += 'DATASET_LABEL\t%s\n' % dataset_label
    outstring += 'COLOR\t%s\n' % dataset_color
    outstring += 'FIELD_COLORS\t%s\n' % '\t'.join(field_colors)
    outstring += 'FIELD_LABELS\t%s\n' % '\t'.join(field_labels)    
    
    if legend:
        outstring += 'LEGEND_TITLE\tDataset legend\n'
        outstring += 'LEGEND_SHAPES\t%s\n' % '\t'.join(['1']*len(fields))
        outstring += 'LEGEND_COLORS\t%s\n' % '\t'.join(field_colors)
        outstring += 'LEGEND_LABELS\t%s\n' % '\t'.join(field_labels)
    
    outstring += 'MARGIN\t%s\n' % margin
    outstring += 'WIDTH\t%s\n' % width

    if unstacked:
        outstring += 'ALIGN_FIELDS\t1\n'
        
    outstring += 'DATA\n'
    for index, row in metadata.iterrows():
        outstring += row[tree_ref_col].replace(' ', '_') + '\t%s\n' % '\t'.join([str(row[x]) for x in fields])

    return(outstring)

# %%
fields = ['ET.Diet.Fruit',
 'ET.Diet.Inv',
 'ET.Diet.Nect',
 'ET.Diet.PlantO',
 'ET.Diet.Scav',
 'ET.Diet.Seed',
 'ET.Diet.Vect',
 'ET.Diet.Vend',
 'ET.Diet.Vfish',
 'ET.Diet.Vunk']

bar = format_iTOL_multibar(fields, 
                     host_md, 
                     tree_ref_col='TimeTree_name', 
                     field_colors=['#a6cee3',
                                   '#cab2d6',
                                   '#1f78b4',
                                   '#33a02c',
                                   '#6a3d9a',
                                   '#b2df8a',
                                   '#fb9a99',
                                   '#e31a1c',
                                   '#ff7f00',
                                   '#fdbf6f'], 
                     field_labels=['Fruit',
                                   'Invertebrates',
                                   'Nectar',
                                   'Plants',
                                   'Scavenging',
                                   'Seeds',
                                   'Meat (Ectotherms)',
                                   'Meat (Endotherms)',
                                   'Meat (Fish)',
                                   'Meat (Unknown)'], 
                     dataset_label='Diet Barchart', 
                     dataset_color=None, 
                     legend=True,
                     width=200, 
                     alpha=1.0)

with open(join(itol_dir, 'mantel.itol-diet_bar.txt'), 'w') as f:
    f.write(bar)

# %%
# !head -n 20 ../phylosymbiosis/itol/mantel.itol-diet_bar.txt
